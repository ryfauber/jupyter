# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import psycopg2
import matplotlib.pyplot as pp
import matplotlib.dates as dates
import pylab as pl
import folium
from IPython.display import HTML
import seaborn as sns
from scipy import stats
from folium.plugins import MarkerCluster
import datetime as dt

# %%
HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
#Importing Data and Resolving Datatypes
result = pd.read_csv('/Users/ryan/Desktop/baseline/notebook/baseline_data_for_viewer.csv', header=0, dtype= 'unicode', parse_dates=['date'])

# %%
#generating Productivity Tables
#starting with the start date of the survey
result = result.loc[result['date'] > '2018-05-10']
result['complete'] = pd.to_numeric(result['complete'], errors='coerce')
result['hh_size_hhinfo'] = pd.to_numeric(result['hh_size_hhinfo'], errors='coerce')
result['incomplete'] = pd.to_numeric(result['incomplete'], errors='coerce')
result['perm_unavail'] = pd.to_numeric(result['perm_unavail'], errors='coerce')
result['refusal'] = pd.to_numeric(result['refusal'], errors='coerce')
#grouping by date
prod_table = result[['state_name','complete', 'date']].groupby(['date']).sum()
#generating some averages
prod_table['Total Attempted'] = result[['scto_uuid', 'date']].groupby(['date']).count()
prod_table['Surveyors Working'] = result[['dod_enumerator_id_intro', 'date']].groupby(['date'])['dod_enumerator_id_intro'].nunique()
prod_table['Avg Daily Attempts by Surveyor'] = ((prod_table['Total Attempted'] / prod_table['Surveyors Working']))
prod_table['Avg Daily Completes by Surveyor'] = ((prod_table['complete'] / prod_table['Surveyors Working']))
#rendering the table

(prod_table.loc[:]
    .style
    .background_gradient(cmap='RdBu', low=0, high=0.2,subset=['complete', 'Total Attempted', 'Surveyors Working','Avg Daily Attempts by Surveyor','Avg Daily Completes by Surveyor']))
# Out:
# <style  type="text/css" >
#     #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row0_col0 {
#             background-color:  #f5f6f7;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row0_col1 {
#             background-color:  #f0f4f6;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row0_col2 {
#             background-color:  #9bc9e0;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row0_col3 {
#             background-color:  #f5a886;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row0_col4 {
#             background-color:  #ec9374;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row1_col0 {
#             background-color:  #78b4d5;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row1_col1 {
#             background-color:  #b3d6e8;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row1_col2 {
#             background-color:  #4f9bc7;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row1_col3 {
#             background-color:  #fbd0b9;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row1_col4 {
#             background-color:  #fae8de;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row2_col0 {
#             background-color:  #6a011f;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row2_col1 {
#             background-color:  #67001f;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row2_col2 {
#             background-color:  #6d0220;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row2_col3 {
#             background-color:  #cb4942;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row2_col4 {
#             background-color:  #fae8de;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row3_col0 {
#             background-color:  #4695c4;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row3_col1 {
#             background-color:  #71b0d3;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row3_col2 {
#             background-color:  #4695c4;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row3_col3 {
#             background-color:  #f8f4f2;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row3_col4 {
#             background-color:  #f3f5f6;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row4_col0 {
#             background-color:  #3885bc;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row4_col1 {
#             background-color:  #96c7df;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row4_col2 {
#             background-color:  #5ca3cb;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row4_col3 {
#             background-color:  #f9ede5;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row4_col4 {
#             background-color:  #d7e8f1;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row5_col0 {
#             background-color:  #4f9bc7;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row5_col1 {
#             background-color:  #3c8abe;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row5_col2 {
#             background-color:  #3b88be;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row5_col3 {
#             background-color:  #e1edf3;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row5_col4 {
#             background-color:  #f9eee7;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row6_col0 {
#             background-color:  #3b88be;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row6_col1 {
#             background-color:  #4695c4;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row6_col2 {
#             background-color:  #3885bc;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row6_col3 {
#             background-color:  #eff3f5;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row6_col4 {
#             background-color:  #f7f6f6;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row7_col0 {
#             background-color:  #3783bb;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row7_col1 {
#             background-color:  #3783bb;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row7_col2 {
#             background-color:  #3783bb;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row7_col3 {
#             background-color:  #e0ecf3;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row7_col4 {
#             background-color:  #f3f5f6;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row8_col0 {
#             background-color:  #f3f5f6;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row8_col1 {
#             background-color:  #f8f4f2;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row8_col2 {
#             background-color:  #a7d0e4;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row8_col3 {
#             background-color:  #f09c7b;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row8_col4 {
#             background-color:  #f3a481;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row9_col0 {
#             background-color:  #67001f;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row9_col1 {
#             background-color:  #67001f;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row9_col2 {
#             background-color:  #67001f;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row9_col3 {
#             background-color:  #3783bb;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row9_col4 {
#             background-color:  #3783bb;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row10_col0 {
#             background-color:  #7f0823;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row10_col1 {
#             background-color:  #810823;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row10_col2 {
#             background-color:  #ab162a;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row10_col3 {
#             background-color:  #67001f;
#         }    #T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row10_col4 {
#             background-color:  #67001f;
#         }</style>
# <table id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >complete</th>
#         <th class="col_heading level0 col1" >Total Attempted</th>
#         <th class="col_heading level0 col2" >Surveyors Working</th>
#         <th class="col_heading level0 col3" >Avg Daily Attempts by Surveyor</th>
#         <th class="col_heading level0 col4" >Avg Daily Completes by Surveyor</th>
#     </tr>    <tr>
#         <th class="index_name level0" >date</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601level0_row0" class="row_heading level0 row0" >2018-05-11 00:00:00</th>
#         <td id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row0_col0" class="data row0 col0" >234</td>
#         <td id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row0_col1" class="data row0 col1" >621</td>
#         <td id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row0_col2" class="data row0 col2" >257</td>
#         <td id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row0_col3" class="data row0 col3" >2.41634</td>
#         <td id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row0_col4" class="data row0 col4" >0.910506</td>
#     </tr>    <tr>
#         <th id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601level0_row1" class="row_heading level0 row1" >2018-05-12 00:00:00</th>
#         <td id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row1_col0" class="data row1 col0" >337</td>
#         <td id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row1_col1" class="data row1 col1" >774</td>
#         <td id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row1_col2" class="data row1 col2" >294</td>
#         <td id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row1_col3" class="data row1 col3" >2.63265</td>
#         <td id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row1_col4" class="data row1 col4" >1.14626</td>
#     </tr>    <tr>
#         <th id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601level0_row2" class="row_heading level0 row2" >2018-05-13 00:00:00</th>
#         <td id="T_c4fcf1f6_5cc8_11e8_ae4a_1600c1905601row2_col0" cl

# %%
#generating Productivity Tables by State, Dist
#grouping by date
result = result.loc[result['date'] > '2018-05-10']
prod = result[['state_name','dist_name','complete', 'date']].groupby(['state_name', 'dist_name', 'date']).sum()

#generating some averages
prod['Total Attempted'] = result[['scto_uuid', 'state_name', 'dist_name', 'date']].groupby(['state_name', 'dist_name', 'date']).count()
prod['Avg Daily Surveyors Working'] = result[['dod_enumerator_id_intro', 'state_name', 'dist_name', 'date']].groupby(['state_name', 'dist_name', 'date'])['dod_enumerator_id_intro'].nunique()
prod['Avg Daily Attempts by Surveyor'] = ((prod['Total Attempted'] / prod['Avg Daily Surveyors Working']))
prod['Avg Daily Completes by Surveyor'] = ((prod['complete'] / prod['Avg Daily Surveyors Working']))
prod.drop(['complete', 'Total Attempted'], 1, inplace = True)
prod = prod.groupby(['state_name', 'dist_name']).mean()
#rendering the table
(prod.loc[:]
    .style
    .background_gradient(cmap='RdBu', low=0, high=0.2,subset=['Avg Daily Surveyors Working','Avg Daily Attempts by Surveyor','Avg Daily Completes by Surveyor']))
# Out:
# <style  type="text/css" >
#     #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row0_col0 {
#             background-color:  #f8bfa4;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row0_col1 {
#             background-color:  #67001f;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row0_col2 {
#             background-color:  #fcdecd;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row1_col0 {
#             background-color:  #f6af8e;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row1_col1 {
#             background-color:  #840924;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row1_col2 {
#             background-color:  #f3f5f6;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row2_col0 {
#             background-color:  #87beda;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row2_col1 {
#             background-color:  #c2383a;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row2_col2 {
#             background-color:  #f9f0eb;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row3_col0 {
#             background-color:  #3783bb;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row3_col1 {
#             background-color:  #eb9172;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row3_col2 {
#             background-color:  #d5e7f1;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row4_col0 {
#             background-color:  #c5dfec;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row4_col1 {
#             background-color:  #ae172a;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row4_col2 {
#             background-color:  #62a7ce;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row5_col0 {
#             background-color:  #edf2f5;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row5_col1 {
#             background-color:  #f9c6ac;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row5_col2 {
#             background-color:  #ef9979;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row6_col0 {
#             background-color:  #f5f6f7;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row6_col1 {
#             background-color:  #b1182b;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row6_col2 {
#             background-color:  #ef9979;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row7_col0 {
#             background-color:  #fbceb7;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row7_col1 {
#             background-color:  #a2cde3;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row7_col2 {
#             background-color:  #cf5246;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row8_col0 {
#             background-color:  #b8d8e9;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row8_col1 {
#             background-color:  #e3edf3;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row8_col2 {
#             background-color:  #67001f;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row9_col0 {
#             background-color:  #f9c4a9;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row9_col1 {
#             background-color:  #fcd7c2;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row9_col2 {
#             background-color:  #f5aa89;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row10_col0 {
#             background-color:  #c0dceb;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row10_col1 {
#             background-color:  #e37e64;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row10_col2 {
#             background-color:  #d25849;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row11_col0 {
#             background-color:  #f7b99c;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row11_col1 {
#             background-color:  #fbe4d6;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row11_col2 {
#             background-color:  #b6d7e8;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row12_col0 {
#             background-color:  #d7e8f1;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row12_col1 {
#             background-color:  #db6b55;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row12_col2 {
#             background-color:  #a21328;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row13_col0 {
#             background-color:  #cf5246;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row13_col1 {
#             background-color:  #fddbc7;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row13_col2 {
#             background-color:  #84bcd9;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row14_col0 {
#             background-color:  #7bb6d6;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row14_col1 {
#             background-color:  #a9d1e5;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row14_col2 {
#             background-color:  #bddbea;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row15_col0 {
#             background-color:  #a81529;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row15_col1 {
#             background-color:  #f2a17f;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row15_col2 {
#             background-color:  #d7e8f1;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row16_col0 {
#             background-color:  #f9eee7;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row16_col1 {
#             background-color:  #dbeaf2;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row16_col2 {
#             background-color:  #d8e9f1;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row17_col0 {
#             background-color:  #fcd5bf;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row17_col1 {
#             background-color:  #6eaed2;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row17_col2 {
#             background-color:  #bddbea;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row18_col0 {
#             background-color:  #d4e6f1;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row18_col1 {
#             background-color:  #f6f7f7;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row18_col2 {
#             background-color:  #3783bb;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row19_col0 {
#             background-color:  #67001f;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row19_col1 {
#             background-color:  #b3d6e8;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row19_col2 {
#             background-color:  #e4eef4;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row20_col0 {
#             background-color:  #c2ddec;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row20_col1 {
#             background-color:  #3783bb;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row20_col2 {
#             background-color:  #f8f4f2;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row21_col0 {
#             background-color:  #db6b55;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row21_col1 {
#             background-color:  #a2cde3;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row21_col2 {
#             background-color:  #c0dceb;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row22_col0 {
#             background-color:  #a7d0e4;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row22_col1 {
#             background-color:  #e0ecf3;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row22_col2 {
#             background-color:  #aed3e6;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row23_col0 {
#             background-color:  #a7d0e4;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row23_col1 {
#             background-color:  #aed3e6;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row23_col2 {
#             background-color:  #f8f2ef;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row24_col0 {
#             background-color:  #e37e64;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row24_col1 {
#             background-color:  #fddbc7;
#         }    #T_e3711aae_5cc8_11e8_8a0f_1600c1905601row24_col2 {
#             background-color:  #facab1;
#         }</style>
# <table id="T_e3711aae_5cc8_11e8_8a0f_1600c1905601" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th c

# %%
#labeling as complete only those surveys that actually resulted in a survey (not refusals or perm_unavail)
result.loc[result['incomplete'] == 0, 'complete'] = 1
result.loc[result['refusal'] == 1, 'complete'] = 0
result.loc[result['perm_unavail'] == 1, 'complete'] = 0
#producing a totals table, grouped by state
total = result[['state_name','refusal','perm_unavail','incomplete','complete']].groupby(['state_name']).sum()
total['Total Attempted'] = result[['state_name','scto_uuid']].groupby(['state_name']).count()
#adding a summary row
total.loc['All'] = total.sum()
#rendering the table
total
# Out:
#                 refusal  perm_unavail  incomplete  complete  Total Attempted
# state_name
# ASSAM               1.0          33.0       444.0     707.0           1185.0
# BIHAR              19.0          64.0       890.0     411.0           1383.0
# JHARKHAND           2.0          15.0       278.0     183.0            477.0
# MADHYA PRADESH     12.0          92.0       692.0     511.0           1307.0
# MAHARASHTRA         2.0           5.0       136.0      95.0            238.0
# RAJASTHAN           7.0          29.0       200.0     196.0            432.0
# UTTAR PRADESH      28.0          58.0       977.0     606.0           1669.0
# All                71.0         296.0      3617.0    2709.0           6691.0

# %%
#producing a counts table by district
counts = result[['state_name','dist_name','refusal','incomplete','complete', 'perm_unavail']].groupby(['state_name','dist_name']).sum()
#adding total attemped
counts['Total Attempted'] = result[['state_name','dist_name','dod_enumerator_id_intro']].groupby(['state_name','dist_name']).count()
#converting to percentages
counts['% Refusal'] = ((counts['refusal'] / counts['Total Attempted']))
counts['% Incomplete'] = ((counts['incomplete'] / counts['Total Attempted']))
counts['% Unavailable'] = ((counts['perm_unavail'] / counts['Total Attempted']))
#dropping the number columns
counts = counts.drop(columns=['refusal', 'incomplete','perm_unavail'])
counts = counts[['% Refusal','% Unavailable', '% Incomplete','complete','Total Attempted']]
#formatting and rendering the table
(counts.loc[:]
    .style
    .format({'% Refusal': "{:.1%}", '% Unavailable': "{:.1%}",'% Incomplete': "{:.1%}"})
    .background_gradient(cmap='RdBu', low=0, high=0.2,subset=['complete', 'Total Attempted'])
    .background_gradient(cmap='coolwarm', low=0.5, high=0.1,subset=['% Refusal', '% Incomplete', '% Unavailable']))
# Out:
# <style  type="text/css" >
#     #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row0_col0 {
#             background-color:  #a3c2fe;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row0_col1 {
#             background-color:  #c0d4f5;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row0_col2 {
#             background-color:  #b2ccfb;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row0_col3 {
#             background-color:  #f9efe9;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row0_col4 {
#             background-color:  #d05548;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row1_col0 {
#             background-color:  #a3c2fe;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row1_col1 {
#             background-color:  #b3cdfb;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row1_col2 {
#             background-color:  #cad8ef;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row1_col3 {
#             background-color:  #f9ede5;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row1_col4 {
#             background-color:  #d7634f;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row2_col0 {
#             background-color:  #a3c2fe;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row2_col1 {
#             background-color:  #d1dae9;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row2_col2 {
#             background-color:  #e3d9d3;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row2_col3 {
#             background-color:  #e0ecf3;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row2_col4 {
#             background-color:  #f7b99c;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row3_col0 {
#             background-color:  #afcafc;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row3_col1 {
#             background-color:  #a3c2fe;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row3_col2 {
#             background-color:  #ead5c9;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row3_col3 {
#             background-color:  #5ca3cb;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row3_col4 {
#             background-color:  #f9f0eb;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row4_col0 {
#             background-color:  #a3c2fe;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row4_col1 {
#             background-color:  #a5c3fe;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row4_col2 {
#             background-color:  #a3c2fe;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row4_col3 {
#             background-color:  #3783bb;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row4_col4 {
#             background-color:  #f8bb9e;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row5_col0 {
#             background-color:  #bfd3f6;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row5_col1 {
#             background-color:  #c7d7f0;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row5_col2 {
#             background-color:  #f4987a;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row5_col3 {
#             background-color:  #fcd7c2;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row5_col4 {
#             background-color:  #fcdecd;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row6_col0 {
#             background-color:  #b9d0f9;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row6_col1 {
#             background-color:  #a9c6fd;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row6_col2 {
#             background-color:  #f7bca1;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row6_col3 {
#             background-color:  #ef9979;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row6_col4 {
#             background-color:  #d6604d;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row7_col0 {
#             background-color:  #a3c2fe;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row7_col1 {
#             background-color:  #aec9fc;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row7_col2 {
#             background-color:  #ca3b37;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row7_col3 {
#             background-color:  #d6604d;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row7_col4 {
#             background-color:  #fdddcb;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row8_col0 {
#             background-color:  #f2c9b4;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row8_col1 {
#             background-color:  #f6bfa6;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row8_col2 {
#             background-color:  #dd5f4b;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row8_col3 {
#             background-color:  #ef9979;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row8_col4 {
#             background-color:  #b8d8e9;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row9_col0 {
#             background-color:  #f5c1a9;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row9_col1 {
#             background-color:  #dadce0;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row9_col2 {
#             background-color:  #f7b396;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row9_col3 {
#             background-color:  #f09c7b;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row9_col4 {
#             background-color:  #ee9677;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row10_col0 {
#             background-color:  #b2ccfb;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row10_col1 {
#             background-color:  #c3d5f4;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row10_col2 {
#             background-color:  #f18f71;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row10_col3 {
#             background-color:  #f5aa89;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row10_col4 {
#             background-color:  #f8bda1;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row11_col0 {
#             background-color:  #b5cdfa;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row11_col1 {
#             background-color:  #b3cdfb;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row11_col2 {
#             background-color:  #f7b99e;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row11_col3 {
#             background-color:  #fbccb4;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row11_col4 {
#             background-color:  #ee9677;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row12_col0 {
#             background-color:  #a3c2fe;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row12_col1 {
#             background-color:  #ead5c9;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row12_col2 {
#             background-color:  #f08a6c;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row12_col3 {
#             background-color:  #f5aa89;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row12_col4 {
#             background-color:  #fcd7c2;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row13_col0 {
#             background-color:  #bcd2f7;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row13_col1 {
#             background-color:  #e6d7cf;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row13_col2 {
#             background-color:  #e3d9d3;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row13_col3 {
#             background-color:  #ea8e70;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row13_col4 {
#             background-color:  #c2383a;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row14_col0 {
#             background-color:  #b7cff9;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row14_col1 {
#             background-color:  #b3cdfb;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row14_col2 {
#             background-color:  #f7aa8c;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row14_col3 {
#             background-color:  #81bad8;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row14_col4 {
#             background-color:  #bbdaea;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601row15_col0 {
#             background-color:  #e5d8d1;
#         }    #T_0e7d8dcc_5cc9_11e8_8e88_1600c1905601r

# %%
#hh_size
h = sorted(result['hh_size_hhinfo'].dropna())  #sorted

fit = stats.norm.pdf(h, np.mean(h), np.std(h))  #this is a fitting indeed

pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title("Distribution of HH Size")
pl.show()

# %%
#generating the map
a = result.gps_location_end.str.split(' ').dropna()
b = pd.DataFrame((item for item in a), columns = ['lat','long','alt','acc'])
b['lat'] = pd.to_numeric(b['lat'], errors='coerce')
b['long'] = pd.to_numeric(b['long'], errors='coerce')

# %%
lat = b['lat'].values
lon = b['long'].values

url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'World_Street_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service


map_osm = folium.Map(location=[b['lat'].mean(), 
   b['long'].mean()],zoom_start=5, control_scale = True, tiles=tileset, attr='USGS style')

mc = folium.plugins.MarkerCluster()

for row in b.itertuples():
    mc.add_child(folium.Marker(location=[row.lat,  row.long]))

map_osm.add_child(mc)

map_osm.get_root().add_child(folium.Element("<h1>Submitted Forms Mapped by GPS</h1>"))
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, MetaData
import sqlalchemy
from sqlalchemy import Integer, String, Float
from sqlalchemy import Column,Integer,Sequence, String, Boolean
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
import psycopg2
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import seaborn
import scipy.stats as stats
import pylab as pl
import folium
from IPython.display import HTML
import seaborn as sns

# %%
HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
result = pd.read_excel('/Users/ryan/Desktop/may12_portaldata.xlsx', encoding= 'utf-8-sig')

result['hh_size_hhinfo'] = pd.to_numeric(result['hh_size_hhinfo'], errors='coerce')

result.loc[result['incomplete'] == 0, 'complete'] = 1
result.loc[result['refusal'] == 1, 'complete'] = 0
result.loc[result['perm_unavail'] == 1, 'complete'] = 0

# %%
counts = result[['state_name','dist_name','refusal','incomplete','complete', 'perm_unavail']].groupby(['state_name','dist_name']).sum()
counts['attempted'] = result[['state_name','dist_name','dod_enumerator_id_intro']].groupby(['state_name','dist_name']).count()

def highlight_max_back(data, color='red'):
    '''
    highlight the maximum in a Series or DataFrame
    '''
    attr = 'background-color: {}'.format(color)
    if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
        is_max = data == data.max()
        return [attr if v else '' for v in is_max]
    else:  # from .apply(axis=None)
        is_max = data == data.max().max()
        return pd.DataFrame(np.where(is_max, attr, ''),
                            index=data.index, columns=data.columns)
    
def highlight_min_back(data, color='green'):
    '''
    highlight the maximum in a Series or DataFrame
    '''
    attr = 'background-color: {}'.format(color)
    if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
        is_min = data == data.min()
        return [attr if v else '' for v in is_min]
    else:  # from .apply(axis=None)
        is_min = data == data.min().min()
        return pd.DataFrame(np.where(is_min, attr, ''),
                            index=data.index, columns=data.columns) 

counts['total'] = counts.sum(axis=1)


(counts.loc[:]
    .style
    .background_gradient(cmap='RdBu', low=0, high=0.2,subset=['complete', 'attempted', 'total'])
    .background_gradient(cmap='coolwarm', low=0.5, high=0.1,subset=['refusal', 'incomplete', 'perm_unavail']))
# Out:
# <style  type="text/css" >
#     #T_d52c14e2_5623_11e8_b9af_1600c1905601row0_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row0_col1 {
#             background-color:  #bed2f6;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row0_col2 {
#             background-color:  #f6af8e;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row0_col3 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row0_col4 {
#             background-color:  #d7634f;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row0_col5 {
#             background-color:  #d7634f;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row1_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row1_col1 {
#             background-color:  #b9d0f9;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row1_col2 {
#             background-color:  #f9c2a7;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row1_col3 {
#             background-color:  #adc9fd;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row1_col4 {
#             background-color:  #da6853;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row1_col5 {
#             background-color:  #da6853;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row2_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row2_col1 {
#             background-color:  #e3d9d3;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row2_col2 {
#             background-color:  #ddebf2;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row2_col3 {
#             background-color:  #d3dbe7;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row2_col4 {
#             background-color:  #f8f2ef;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row2_col5 {
#             background-color:  #f8f1ed;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row3_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row3_col1 {
#             background-color:  #f0cdbb;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row3_col2 {
#             background-color:  #aed3e6;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row3_col3 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row3_col4 {
#             background-color:  #e7f0f4;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row3_col5 {
#             background-color:  #e9f0f4;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row4_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row4_col1 {
#             background-color:  #b9d0f9;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row4_col2 {
#             background-color:  #3783bb;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row4_col3 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row4_col4 {
#             background-color:  #fce2d2;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row4_col5 {
#             background-color:  #fce2d2;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row5_col0 {
#             background-color:  #ecd3c5;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row5_col1 {
#             background-color:  #f0cdbb;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row5_col2 {
#             background-color:  #fbccb4;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row5_col3 {
#             background-color:  #cad8ef;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row5_col4 {
#             background-color:  #f9ebe3;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row5_col5 {
#             background-color:  #faeae1;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row6_col0 {
#             background-color:  #ccd9ed;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row6_col1 {
#             background-color:  #dfdbd9;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row6_col2 {
#             background-color:  #f6af8e;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row6_col3 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row6_col4 {
#             background-color:  #f6af8e;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row6_col5 {
#             background-color:  #f6af8e;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row7_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row7_col1 {
#             background-color:  #dd5f4b;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row7_col2 {
#             background-color:  #f9c2a7;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row7_col3 {
#             background-color:  #adc9fd;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row7_col4 {
#             background-color:  #a5cee3;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row7_col5 {
#             background-color:  #a7d0e4;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row8_col0 {
#             background-color:  #ecd3c5;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row8_col1 {
#             background-color:  #ca3b37;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row8_col2 {
#             background-color:  #f7f6f6;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row8_col3 {
#             background-color:  #d3dbe7;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row8_col4 {
#             background-color:  #3783bb;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row8_col5 {
#             background-color:  #3783bb;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row9_col0 {
#             background-color:  #ecd3c5;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row9_col1 {
#             background-color:  #e8d6cc;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row9_col2 {
#             background-color:  #f8f1ed;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row9_col3 {
#             background-color:  #c0d4f5;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row9_col4 {
#             background-color:  #f9ebe3;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row9_col5 {
#             background-color:  #faeae1;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row10_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row10_col1 {
#             background-color:  #edd1c2;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row10_col2 {
#             background-color:  #fdddcb;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row10_col3 {
#             background-color:  #b7cff9;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row10_col4 {
#             background-color:  #fce2d2;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row10_col5 {
#             background-color:  #fce2d2;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row11_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row11_col1 {
#             background-color:  #dadce0;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row11_col2 {
#             background-color:  #f8f1ed;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row11_col3 {
#             background-color:  #adc9fd;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row11_col4 {
#             background-color:  #fbceb7;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row11_col5 {
#             background-color:  #fbccb4;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row12_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row12_col1 {
#             background-color:  #f2c9b4;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row12_col2 {
#             background-color:  #d35a4a;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row12_col3 {
#             background-color:  #adc9fd;
#         }    #T_d52c14e2_5623_11e8_b9af_1600c1905601row12_col4

# %%
h = sorted(result['hh_size_hhinfo'].dropna())  #sorted

fit = stats.norm.pdf(h, np.mean(h), np.std(h))  #this is a fitting indeed

pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title("Distribution of HH Size")
pl.show()

# %%
#x = np.linspace(0, 2 * np.pi, 400)
#y = np.sin(x ** 2)

#pl.close('all')


#f, (ax1, ax2) = pl.subplots(1, 2, sharey=True)
#ax1.plot(x, y)
#ax1.set_title('Sharing Y axis')
#ax2.scatter(x, y)

# %%
a = result.gps_location_end.str.split(' ').dropna()
b = pd.DataFrame((item for item in a), columns = ['lat','long','alt','acc'])
b['lat'] = pd.to_numeric(b['lat'], errors='coerce')
b['long'] = pd.to_numeric(b['long'], errors='coerce')
b['ref'] = result['refusal']
b['comp'] = result['incomplete']

# %%
lat = b['lat'].values
lon = b['long'].values
colors = {1 : 'red', 0 : 'blue'}


map_osm = folium.Map(location=[26.222534, 82],zoom_start=6)
b.apply(lambda row:folium.CircleMarker(location=[row["lat"], row["long"]], 
                                              radius=1,color=colors[row['comp']])
                                             .add_to(map_osm), axis=1)


iframe = map_osm._repr_html_()
display(HTML(iframe))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

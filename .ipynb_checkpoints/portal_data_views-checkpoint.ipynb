# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import psycopg2
import matplotlib.pyplot as pp
import matplotlib.dates as dates
import pylab as pl
import folium
from IPython.display import HTML
import seaborn as sns
from scipy import stats
from folium.plugins import MarkerCluster
import datetime as dt

# %%
HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
#Importing Data and Resolving Datatypes
result = pd.read_csv('/Users/ryan/Desktop/baseline/notebook/baseline_data_for_viewer.csv', header=0, dtype= 'unicode', parse_dates=['date'])   
#starting with the start date of the survey
result = result.loc[result['date'] > '2018-05-10']
result = result.reset_index()
result['complete'].fillna(0, inplace=True)
result['complete'] = pd.to_numeric(result['complete'], errors='coerce')
result.loc[result['complete'] == 0 ,'complete'] = result['calc_comp']

# %%
#generating Productivity Tables
result['complete'] = pd.to_numeric(result['complete'], errors='coerce')
result['hh_size_hhinfo'] = pd.to_numeric(result['hh_size_hhinfo'], errors='coerce')
result['incomplete'] = pd.to_numeric(result['incomplete'], errors='coerce')
result['perm_unavail'] = pd.to_numeric(result['perm_unavail'], errors='coerce')
result['refusal'] = pd.to_numeric(result['refusal'], errors='coerce')
#grouping by date
prod_table = result[['state_name','complete', 'date']].groupby(['date']).sum()
#generating some averages
prod_table['Total Attempted'] = result[['scto_uuid', 'date']].groupby(['date']).count()
prod_table['Surveyors Working'] = result[['dod_enumerator_id_intro', 'date']].groupby(['date'])['dod_enumerator_id_intro'].nunique()
prod_table['Avg Daily Attempts by Surveyor'] = ((prod_table['Total Attempted'] / prod_table['Surveyors Working']))
prod_table['Avg Daily Completes by Surveyor'] = ((prod_table['complete'] / prod_table['Surveyors Working']))
#rendering the table
(prod_table.loc[:]
    .style
    .set_caption("Productivity by Date")
    .background_gradient(cmap='RdBu', low=0, high=0.2,subset=['complete', 'Total Attempted', 'Surveyors Working','Avg Daily Attempts by Surveyor','Avg Daily Completes by Surveyor']))
# Out:
# <style  type="text/css" >
#     #T_d66556ac_5e46_11e8_924d_1600c1905601row0_col0 {
#             background-color:  #f9eee7;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row0_col1 {
#             background-color:  #f2f5f6;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row0_col2 {
#             background-color:  #a2cde3;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row0_col3 {
#             background-color:  #dc6e57;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row0_col4 {
#             background-color:  #67001f;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row1_col0 {
#             background-color:  #a9d1e5;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row1_col1 {
#             background-color:  #b3d6e8;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row1_col2 {
#             background-color:  #569fc9;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row1_col3 {
#             background-color:  #f7b99c;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row1_col4 {
#             background-color:  #e27b62;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row2_col0 {
#             background-color:  #67001f;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row2_col1 {
#             background-color:  #67001f;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row2_col2 {
#             background-color:  #67001f;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row2_col3 {
#             background-color:  #67001f;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row2_col4 {
#             background-color:  #d25849;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row3_col0 {
#             background-color:  #5ca3cb;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row3_col1 {
#             background-color:  #78b4d5;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row3_col2 {
#             background-color:  #4f9bc7;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row3_col3 {
#             background-color:  #f5f6f7;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row3_col4 {
#             background-color:  #fbe4d6;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row4_col0 {
#             background-color:  #65a9cf;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row4_col1 {
#             background-color:  #96c7df;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row4_col2 {
#             background-color:  #65a9cf;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row4_col3 {
#             background-color:  #f9f0eb;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row4_col4 {
#             background-color:  #faeae1;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row5_col0 {
#             background-color:  #3783bb;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row5_col1 {
#             background-color:  #3885bc;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row5_col2 {
#             background-color:  #3e8cbf;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row5_col3 {
#             background-color:  #b6d7e8;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row5_col4 {
#             background-color:  #f7f5f4;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row6_col0 {
#             background-color:  #3a87bd;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row6_col1 {
#             background-color:  #3e8cbf;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row6_col2 {
#             background-color:  #3783bb;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row6_col3 {
#             background-color:  #dae9f2;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row6_col4 {
#             background-color:  #fae7dc;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row7_col0 {
#             background-color:  #4291c2;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row7_col1 {
#             background-color:  #3783bb;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row7_col2 {
#             background-color:  #3a87bd;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row7_col3 {
#             background-color:  #bddbea;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row7_col4 {
#             background-color:  #fce0d0;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row8_col0 {
#             background-color:  #7bb6d6;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row8_col1 {
#             background-color:  #90c4dd;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row8_col2 {
#             background-color:  #65a9cf;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row8_col3 {
#             background-color:  #f7f5f4;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row8_col4 {
#             background-color:  #fddbc7;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row9_col0 {
#             background-color:  #6a011f;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row9_col1 {
#             background-color:  #6a011f;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row9_col2 {
#             background-color:  #67001f;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row9_col3 {
#             background-color:  #3783bb;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row9_col4 {
#             background-color:  #3783bb;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row10_col0 {
#             background-color:  #c0dceb;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row10_col1 {
#             background-color:  #acd2e5;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row10_col2 {
#             background-color:  #9bc9e0;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row10_col3 {
#             background-color:  #e4eef4;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row10_col4 {
#             background-color:  #f7b596;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row11_col0 {
#             background-color:  #6eaed2;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row11_col1 {
#             background-color:  #5fa5cd;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row11_col2 {
#             background-color:  #5fa5cd;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row11_col3 {
#             background-color:  #cae1ee;
#         }    #T_d66556ac_5e46_11e8_924d_1600c1905601row11_col4 {
#             background-color:  #fcdfcf;
#         }</style>
# <table id="T_d66556ac_5e46_11e8_924d_1600c1905601" ><caption>Productivity by Date</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >complete</th>
#         <th class="col_heading level0 col1" >Total Attempted</th>
#         <th class="col_heading level0 col2" >Surveyors Working</th>
#         <th class="col_heading level0 col3" >Avg Daily Attempts by Surveyor</th>
#         <th class="col_heading level0 col4" >Avg Daily Completes by Surveyor</th>
#     </tr>    <tr>
#         <th class="index_name level0" >date</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d66556ac_5e46_11e8_924d_1600c1905601level0_row0" class="row_heading level0 row0" >2018-05-11 00:00:00</th>
#         <td id="T_d66556ac_5e46_11e8_924d_1600c1905601row0_col0" class="data row0 col0" >356.791</td>
#         <td id="T_d66556ac_5e46_11e8_924d_1600c1905601row0_col1" class="data row0 col1" >614</td>
#         <td id="T_d66556ac_5e46_11e8_924d_1600c1905601row0_col2" class="data row0 col2" >254</td>
#         <td id="T_d66556ac_5e46_11e8_924d_1600c1905601row0_col3" class="data row0 col3" >2.41732</td>
#         <td id="T_d66556ac_5e46_11e8_924d_1600c1905601row0_col4" class="data row0 col4" >1.40469</td>
#     </tr>    <tr>
#         <th id="T_d66556ac_5e46_11e8_924d_1600c1905601level0_row1" class="row_heading level0 row1" >2018-05-12 00:00:00</th>
#         <td id="T_d66556ac_5e46_11e8_924d_1600c1905601row1_col0" class="data row1 col0" >500.592</td>
#         <td id="T_d66556ac_5e46_11e8_924d_160

# %%
#labeling as complete only those surveys that actually resulted in a survey (not refusals or perm_unavail)
#producing a totals table, grouped by state
total = result[['state_name','refusal','perm_unavail','incomplete','complete']].groupby(['state_name']).sum()
total['Total Attempted'] = result[['state_name','scto_uuid']].groupby(['state_name']).count()
#adding a summary row

#rendering the table
(total[:]
    .style
    .set_caption("Productivity by State")
    .background_gradient(cmap='RdBu', low=0, high=0.2,subset=['complete','Total Attempted'])
    .background_gradient(cmap='coolwarm', low=0.5, high=0.1,subset=['refusal', 'perm_unavail', 'incomplete']))
# Out:
# <style  type="text/css" >
#     #T_d8344452_5e46_11e8_b9c2_1600c1905601row0_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row0_col1 {
#             background-color:  #d7dce3;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row0_col2 {
#             background-color:  #e2dad5;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row0_col3 {
#             background-color:  #6bacd1;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row0_col4 {
#             background-color:  #f6f7f7;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row1_col0 {
#             background-color:  #f7b89c;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row1_col1 {
#             background-color:  #f08a6c;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row1_col2 {
#             background-color:  #e26952;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row1_col3 {
#             background-color:  #bbdaea;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row1_col4 {
#             background-color:  #acd2e5;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row2_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row2_col1 {
#             background-color:  #b7cff9;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row2_col2 {
#             background-color:  #c5d6f2;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row2_col3 {
#             background-color:  #cc4c44;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row2_col4 {
#             background-color:  #bd2d35;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row3_col0 {
#             background-color:  #f2c9b4;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row3_col1 {
#             background-color:  #ca3b37;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row3_col2 {
#             background-color:  #f6a385;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row3_col3 {
#             background-color:  #dbeaf2;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row3_col4 {
#             background-color:  #bddbea;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row4_col0 {
#             background-color:  #aac7fd;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row4_col1 {
#             background-color:  #a3c2fe;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row4_col2 {
#             background-color:  #a3c2fe;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row4_col3 {
#             background-color:  #67001f;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row4_col4 {
#             background-color:  #67001f;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row5_col0 {
#             background-color:  #cad8ef;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row5_col1 {
#             background-color:  #d1dae9;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row5_col2 {
#             background-color:  #b2ccfb;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row5_col3 {
#             background-color:  #bd2d35;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row5_col4 {
#             background-color:  #b3192c;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row6_col0 {
#             background-color:  #ca3b37;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row6_col1 {
#             background-color:  #f7b89c;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row6_col2 {
#             background-color:  #ca3b37;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row6_col3 {
#             background-color:  #3783bb;
#         }    #T_d8344452_5e46_11e8_b9c2_1600c1905601row6_col4 {
#             background-color:  #3783bb;
#         }</style>
# <table id="T_d8344452_5e46_11e8_b9c2_1600c1905601" ><caption>Productivity by State</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >refusal</th>
#         <th class="col_heading level0 col1" >perm_unavail</th>
#         <th class="col_heading level0 col2" >incomplete</th>
#         <th class="col_heading level0 col3" >complete</th>
#         <th class="col_heading level0 col4" >Total Attempted</th>
#     </tr>    <tr>
#         <th class="index_name level0" >state_name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d8344452_5e46_11e8_b9c2_1600c1905601level0_row0" class="row_heading level0 row0" >ASSAM</th>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row0_col0" class="data row0 col0" >3</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row0_col1" class="data row0 col1" >42</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row0_col2" class="data row0 col2" >543</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row0_col3" class="data row0 col3" >1190.52</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row0_col4" class="data row0 col4" >1437</td>
#     </tr>    <tr>
#         <th id="T_d8344452_5e46_11e8_b9c2_1600c1905601level0_row1" class="row_heading level0 row1" >BIHAR</th>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row1_col0" class="data row1 col0" >21</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row1_col1" class="data row1 col1" >103</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row1_col2" class="data row1 col2" >1117</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row1_col3" class="data row1 col3" >1039.89</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row1_col4" class="data row1 col4" >1779</td>
#     </tr>    <tr>
#         <th id="T_d8344452_5e46_11e8_b9c2_1600c1905601level0_row2" class="row_heading level0 row2" >JHARKHAND</th>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row2_col0" class="data row2 col0" >3</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row2_col1" class="data row2 col1" >21</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row2_col2" class="data row2 col2" >358</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row2_col3" class="data row2 col3" >422.451</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row2_col4" class="data row2 col4" >612</td>
#     </tr>    <tr>
#         <th id="T_d8344452_5e46_11e8_b9c2_1600c1905601level0_row3" class="row_heading level0 row3" >MADHYA PRADESH</th>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row3_col0" class="data row3 col0" >18</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row3_col1" class="data row3 col1" >133</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row3_col2" class="data row3 col2" >893</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row3_col3" class="data row3 col3" >952.716</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row3_col4" class="data row3 col4" >1721</td>
#     </tr>    <tr>
#         <th id="T_d8344452_5e46_11e8_b9c2_1600c1905601level0_row4" class="row_heading level0 row4" >MAHARASHTRA</th>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row4_col0" class="data row4 col0" >4</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row4_col1" class="data row4 col1" >9</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row4_col2" class="data row4 col2" >183</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row4_col3" class="data row4 col3" >190.307</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row4_col4" class="data row4 col4" >319</td>
#     </tr>    <tr>
#         <th id="T_d8344452_5e46_11e8_b9c2_1600c1905601level0_row5" class="row_heading level0 row5" >RAJASTHAN</th>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row5_col0" class="data row5 col0" >9</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row5_col1" class="data row5 col1" >37</td>
#         <td id="T_d8344452_5e46_11e8_b9c2_1600c1905601row5_col2" class="data row5 col2" >257</td>

# %%
#generating Productivity Tables by State, Dist
#grouping by date

prod = result[['state_name','dist_name','complete', 'date']].groupby(['state_name', 'dist_name', 'date']).sum()

#generating some averages
prod['Total Attempted'] = result[['scto_uuid', 'state_name', 'dist_name', 'date']].groupby(['state_name', 'dist_name', 'date']).count()
prod['Avg Daily Surveyors Working'] = result[['dod_enumerator_id_intro', 'state_name', 'dist_name', 'date']].groupby(['state_name', 'dist_name', 'date'])['dod_enumerator_id_intro'].nunique()
prod['Avg Daily Attempts by Surveyor'] = ((prod['Total Attempted'] / prod['Avg Daily Surveyors Working']))
prod['Avg Daily Completes by Surveyor'] = ((prod['complete'] / prod['Avg Daily Surveyors Working']))
prod.drop(['complete', 'Total Attempted'], 1, inplace = True)
prod = prod.groupby(['state_name', 'dist_name']).mean()
#rendering the table
(prod.loc[:]
    .style
    .set_caption("Productivity by District")
    .background_gradient(cmap='RdBu', low=0, high=0.2,subset=['Avg Daily Surveyors Working','Avg Daily Attempts by Surveyor','Avg Daily Completes by Surveyor']))
# Out:
# <style  type="text/css" >
#     #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row0_col0 {
#             background-color:  #fae8de;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row0_col1 {
#             background-color:  #67001f;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row0_col2 {
#             background-color:  #f7b99c;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row1_col0 {
#             background-color:  #fac8af;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row1_col1 {
#             background-color:  #6d0220;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row1_col2 {
#             background-color:  #cc4c44;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row2_col0 {
#             background-color:  #a2cde3;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row2_col1 {
#             background-color:  #870a24;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row2_col2 {
#             background-color:  #db6b55;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row3_col0 {
#             background-color:  #3783bb;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row3_col1 {
#             background-color:  #d55d4c;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row3_col2 {
#             background-color:  #e4eef4;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row4_col0 {
#             background-color:  #b1d5e7;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row4_col1 {
#             background-color:  #7c0722;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row4_col2 {
#             background-color:  #fbe4d6;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row5_col0 {
#             background-color:  #cae1ee;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row5_col1 {
#             background-color:  #f6b191;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row5_col2 {
#             background-color:  #fcd5bf;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row6_col0 {
#             background-color:  #edf2f5;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row6_col1 {
#             background-color:  #cf5246;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row6_col2 {
#             background-color:  #f09c7b;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row7_col0 {
#             background-color:  #fbe3d4;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row7_col1 {
#             background-color:  #acd2e5;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row7_col2 {
#             background-color:  #ea8e70;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row8_col0 {
#             background-color:  #96c7df;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row8_col1 {
#             background-color:  #fcdfcf;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row8_col2 {
#             background-color:  #cc4c44;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row9_col0 {
#             background-color:  #fbe5d8;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row9_col1 {
#             background-color:  #f8bb9e;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row9_col2 {
#             background-color:  #f7b596;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row10_col0 {
#             background-color:  #a7d0e4;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row10_col1 {
#             background-color:  #c2383a;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row10_col2 {
#             background-color:  #bb2a34;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row11_col0 {
#             background-color:  #fce0d0;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row11_col1 {
#             background-color:  #f8bfa4;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row11_col2 {
#             background-color:  #d7e8f1;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row12_col0 {
#             background-color:  #f2f5f6;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row12_col1 {
#             background-color:  #e17860;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row12_col2 {
#             background-color:  #67001f;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row13_col0 {
#             background-color:  #e37e64;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row13_col1 {
#             background-color:  #f9f0eb;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row13_col2 {
#             background-color:  #c5dfec;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row14_col0 {
#             background-color:  #87beda;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row14_col1 {
#             background-color:  #c7e0ed;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row14_col2 {
#             background-color:  #f7b99c;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row15_col0 {
#             background-color:  #a51429;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row15_col1 {
#             background-color:  #ce4f45;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row15_col2 {
#             background-color:  #a51429;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row16_col0 {
#             background-color:  #deebf2;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row16_col1 {
#             background-color:  #a9d1e5;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row16_col2 {
#             background-color:  #f3f5f6;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row17_col0 {
#             background-color:  #fce2d2;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row17_col1 {
#             background-color:  #f6f7f7;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row17_col2 {
#             background-color:  #e1edf3;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row18_col0 {
#             background-color:  #7eb8d7;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row18_col1 {
#             background-color:  #fbe5d8;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row18_col2 {
#             background-color:  #e9f0f4;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row19_col0 {
#             background-color:  #67001f;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row19_col1 {
#             background-color:  #f9efe9;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row19_col2 {
#             background-color:  #f7f5f4;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row20_col0 {
#             background-color:  #569fc9;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row20_col1 {
#             background-color:  #3783bb;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row20_col2 {
#             background-color:  #bbdaea;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row21_col0 {
#             background-color:  #e27b62;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row21_col1 {
#             background-color:  #acd2e5;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row21_col2 {
#             background-color:  #f3f5f6;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row22_col0 {
#             background-color:  #aed3e6;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row22_col1 {
#             background-color:  #f3f5f6;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row22_col2 {
#             background-color:  #b1d5e7;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row23_col0 {
#             background-color:  #3f8ec0;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row23_col1 {
#             background-color:  #c7e0ed;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row23_col2 {
#             background-color:  #a5cee3;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row24_col0 {
#             background-color:  #f5a886;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row24_col1 {
#             background-color:  #e7f0f4;
#         }    #T_d9035d9e_5e46_11e8_b6bc_1600c1905601row24_col2 {
#             background-color:  #3783bb;
#         }</style>
# <table id="T_d9035d9e_5e46_11e8_b6bc_1600c1905601" ><caption>Productivity by District</caption>
# <thead>    <tr>

# %%
#producing a counts table by district
counts = result[['state_name','dist_name','refusal','incomplete','complete', 'perm_unavail']].groupby(['state_name','dist_name']).sum()
#adding total attemped
counts['Total Attempted'] = result[['state_name','dist_name','dod_enumerator_id_intro']].groupby(['state_name','dist_name']).count()
#converting to percentages
counts['% Refusal'] = ((counts['refusal'] / counts['Total Attempted']))
counts['% Incomplete'] = ((counts['incomplete'] / counts['Total Attempted']))
counts['% Unavailable'] = ((counts['perm_unavail'] / counts['Total Attempted']))
#dropping the number columns
counts = counts.drop(columns=['refusal', 'incomplete','perm_unavail'])
counts = counts[['% Refusal','% Unavailable', '% Incomplete','complete','Total Attempted']]
#formatting and rendering the table
(counts.loc[:]
    .style
    .set_caption("Form Status by District")
    .format({'% Refusal': "{:.1%}", '% Unavailable': "{:.1%}",'% Incomplete': "{:.1%}"})
    .background_gradient(cmap='RdBu', low=0, high=0.2,subset=['complete', 'Total Attempted'])
    .background_gradient(cmap='coolwarm', low=0.5, high=0.1,subset=['% Refusal', '% Incomplete', '% Unavailable']))
# Out:
# <style  type="text/css" >
#     #T_d9aeec7e_5e46_11e8_867a_1600c1905601row0_col0 {
#             background-color:  #b6cefa;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row0_col1 {
#             background-color:  #cdd9ec;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row0_col2 {
#             background-color:  #adc9fd;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row0_col3 {
#             background-color:  #f9c6ac;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row0_col4 {
#             background-color:  #cf5246;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row1_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row1_col1 {
#             background-color:  #c5d6f2;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row1_col2 {
#             background-color:  #cbd8ee;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row1_col3 {
#             background-color:  #facab1;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row1_col4 {
#             background-color:  #dd7059;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row2_col0 {
#             background-color:  #aec9fc;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row2_col1 {
#             background-color:  #ccd9ed;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row2_col2 {
#             background-color:  #d3dbe7;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row2_col3 {
#             background-color:  #d7e8f1;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row2_col4 {
#             background-color:  #fdd9c4;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row3_col0 {
#             background-color:  #adc9fd;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row3_col1 {
#             background-color:  #adc9fd;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row3_col2 {
#             background-color:  #ebd3c6;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row3_col3 {
#             background-color:  #98c8e0;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row3_col4 {
#             background-color:  #fbe5d8;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row4_col0 {
#             background-color:  #a3c2fe;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row4_col1 {
#             background-color:  #a3c2fe;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row4_col2 {
#             background-color:  #a3c2fe;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row4_col3 {
#             background-color:  #cfe4ef;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row4_col4 {
#             background-color:  #f6b394;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row5_col0 {
#             background-color:  #b7cff9;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row5_col1 {
#             background-color:  #bed2f6;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row5_col2 {
#             background-color:  #ef886b;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row5_col3 {
#             background-color:  #eaf1f5;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row5_col4 {
#             background-color:  #fbe4d6;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row6_col0 {
#             background-color:  #b1cbfc;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row6_col1 {
#             background-color:  #f7b99e;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row6_col2 {
#             background-color:  #f5c0a7;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row6_col3 {
#             background-color:  #fbccb4;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row6_col4 {
#             background-color:  #f19e7d;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row7_col0 {
#             background-color:  #aec9fc;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row7_col1 {
#             background-color:  #aec9fc;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row7_col2 {
#             background-color:  #ca3b37;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row7_col3 {
#             background-color:  #f7b596;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row7_col4 {
#             background-color:  #fbe3d4;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row8_col0 {
#             background-color:  #ebd3c6;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row8_col1 {
#             background-color:  #f29274;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row8_col2 {
#             background-color:  #dc5d4a;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row8_col3 {
#             background-color:  #d4e6f1;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row8_col4 {
#             background-color:  #b3d6e8;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row9_col0 {
#             background-color:  #ead5c9;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row9_col1 {
#             background-color:  #e8d6cc;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row9_col2 {
#             background-color:  #f6bda2;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row9_col3 {
#             background-color:  #f8bda1;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row9_col4 {
#             background-color:  #f4a683;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row10_col0 {
#             background-color:  #aec9fc;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row10_col1 {
#             background-color:  #c4d5f3;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row10_col2 {
#             background-color:  #f29072;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row10_col3 {
#             background-color:  #faeae1;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row10_col4 {
#             background-color:  #fbceb7;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row11_col0 {
#             background-color:  #bed2f6;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row11_col1 {
#             background-color:  #c6d6f1;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row11_col2 {
#             background-color:  #f7ad90;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row11_col3 {
#             background-color:  #fbe4d6;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row11_col4 {
#             background-color:  #f5a886;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row12_col0 {
#             background-color:  #b7cff9;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row12_col1 {
#             background-color:  #f6bda2;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row12_col2 {
#             background-color:  #f08b6e;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row12_col3 {
#             background-color:  #fce2d2;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row12_col4 {
#             background-color:  #fbe4d6;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row13_col0 {
#             background-color:  #b3cdfb;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row13_col1 {
#             background-color:  #f2cbb7;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row13_col2 {
#             background-color:  #e8d6cc;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row13_col3 {
#             background-color:  #e8896c;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row13_col4 {
#             background-color:  #dc6e57;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row14_col0 {
#             background-color:  #b2ccfb;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row14_col1 {
#             background-color:  #c9d7f0;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row14_col2 {
#             background-color:  #f7b599;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row14_col3 {
#             background-color:  #e0ecf3;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row14_col4 {
#             background-color:  #b6d7e8;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601row15_col0 {
#             background-color:  #f6bfa6;
#         }    #T_d9aeec7e_5e46_11e8_867a_1600c1905601r

# %%
#hh_size
h = sorted(result['hh_size_hhinfo'].dropna())  #sorted

fit = stats.norm.pdf(h, np.mean(h), np.std(h))  #this is a fitting indeed

pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title("Distribution of HH Size")
pl.show()

# %%
#generating the map
a = result.gps_location_end.str.split(' ').dropna()
b = pd.DataFrame((item for item in a), columns = ['lat','long','alt','acc'])
b['lat'] = pd.to_numeric(b['lat'], errors='coerce')
b['long'] = pd.to_numeric(b['long'], errors='coerce')

# %%
lat = b['lat'].values
lon = b['long'].values

url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'World_Street_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service


map_osm = folium.Map(location=[b['lat'].mean(), 
   b['long'].mean()],zoom_start=5, control_scale = True, tiles=tileset, attr='USGS style')

mc = folium.plugins.MarkerCluster()

for row in b.itertuples():
    mc.add_child(folium.Marker(location=[row.lat,  row.long]))

map_osm.add_child(mc)

map_osm.get_root().add_child(folium.Element("<h1>Submitted Forms Mapped by GPS</h1>"))
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

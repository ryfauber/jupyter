# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import psycopg2
import matplotlib.pyplot as pp
import pylab as pl
import folium
from IPython.display import HTML
import seaborn as sns

HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
result = pd.read_excel('/Users/ryan/Desktop/may12_portaldata.xlsx', encoding= 'utf-8-sig')

result['hh_size_hhinfo'] = pd.to_numeric(result['hh_size_hhinfo'], errors='coerce')

result.loc[result['incomplete'] == 0, 'complete'] = 1
result.loc[result['refusal'] == 1, 'complete'] = 0
result.loc[result['perm_unavail'] == 1, 'complete'] = 0

# %%
counts = result[['state_name','dist_name','refusal','incomplete','complete', 'perm_unavail']].groupby(['state_name','dist_name']).sum()
counts['Total Attempted'] = result[['state_name','dist_name','dod_enumerator_id_intro']].groupby(['state_name','dist_name']).count()
counts['% Refusal'] = ((counts['refusal'] / counts['Total Attempted']))
counts['% Incomplete'] = ((counts['incomplete'] / counts['Total Attempted']))
counts['% Unavailable'] = ((counts['perm_unavail'] / counts['Total Attempted']))
counts = counts.drop(columns=['refusal', 'incomplete','perm_unavail'])
counts = counts[['% Refusal','% Unavailable', '% Incomplete','complete','Total Attempted']]

(counts.loc[:]
    .style
    .format({'% Refusal': "{:.1%}", '% Unavailable': "{:.1%}",'% Incomplete': "{:.1%}"})
    .background_gradient(cmap='RdBu', low=0, high=0.2,subset=['complete', 'Total Attempted'])
    .background_gradient(cmap='coolwarm', low=0.5, high=0.1,subset=['% Refusal', '% Incomplete', '% Unavailable']))
# Out:
# <style  type="text/css" >
#     #T_2bbbc86c_562b_11e8_abb4_1600c1905601row0_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row0_col1 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row0_col2 {
#             background-color:  #e9d5cb;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row0_col3 {
#             background-color:  #f6af8e;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row0_col4 {
#             background-color:  #d7634f;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row1_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row1_col1 {
#             background-color:  #aec9fc;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row1_col2 {
#             background-color:  #d4dbe6;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row1_col3 {
#             background-color:  #f9c2a7;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row1_col4 {
#             background-color:  #da6853;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row2_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row2_col1 {
#             background-color:  #c0d4f5;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row2_col2 {
#             background-color:  #edd1c2;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row2_col3 {
#             background-color:  #ddebf2;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row2_col4 {
#             background-color:  #f8f2ef;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row3_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row3_col1 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row3_col2 {
#             background-color:  #f5c1a9;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row3_col3 {
#             background-color:  #aed3e6;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row3_col4 {
#             background-color:  #e7f0f4;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row4_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row4_col1 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row4_col2 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row4_col3 {
#             background-color:  #3783bb;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row4_col4 {
#             background-color:  #fce2d2;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row5_col0 {
#             background-color:  #e5d8d1;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row5_col1 {
#             background-color:  #bbd1f8;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row5_col2 {
#             background-color:  #f7a688;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row5_col3 {
#             background-color:  #fbccb4;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row5_col4 {
#             background-color:  #f9ebe3;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row6_col0 {
#             background-color:  #d3dbe7;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row6_col1 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row6_col2 {
#             background-color:  #f6a385;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row6_col3 {
#             background-color:  #f6af8e;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row6_col4 {
#             background-color:  #f6af8e;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row7_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row7_col1 {
#             background-color:  #a7c5fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row7_col2 {
#             background-color:  #ca3b37;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row7_col3 {
#             background-color:  #f9c2a7;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row7_col4 {
#             background-color:  #a5cee3;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row8_col0 {
#             background-color:  #ccd9ed;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row8_col1 {
#             background-color:  #b5cdfa;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row8_col2 {
#             background-color:  #e26952;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row8_col3 {
#             background-color:  #f7f6f6;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row8_col4 {
#             background-color:  #3783bb;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row9_col0 {
#             background-color:  #e5d8d1;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row9_col1 {
#             background-color:  #b6cefa;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row9_col2 {
#             background-color:  #f5c2aa;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row9_col3 {
#             background-color:  #f8f1ed;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row9_col4 {
#             background-color:  #f9ebe3;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row10_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row10_col1 {
#             background-color:  #b1cbfc;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row10_col2 {
#             background-color:  #f6a586;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row10_col3 {
#             background-color:  #fdddcb;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row10_col4 {
#             background-color:  #fce2d2;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row11_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row11_col1 {
#             background-color:  #aac7fd;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row11_col2 {
#             background-color:  #f2cab5;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row11_col3 {
#             background-color:  #f8f1ed;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row11_col4 {
#             background-color:  #fbceb7;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row12_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row12_col1 {
#             background-color:  #aac7fd;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row12_col2 {
#             background-color:  #d1493f;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row12_col3 {
#             background-color:  #d35a4a;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row12_col4 {
#             background-color:  #f8bfa4;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row13_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row13_col1 {
#             background-color:  #c7d7f0;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row13_col2 {
#             background-color:  #d7dce3;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row13_col3 {
#             background-color:  #ce4f45;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row13_col4 {
#             background-color:  #b41c2d;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row14_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row14_col1 {
#             background-color:  #aec9fc;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row14_col2 {
#             background-color:  #f39778;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row14_col3 {
#             background-color:  #a2cde3;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row14_col4 {
#             background-color:  #569fc9;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601row15_col0 {
#             background-color:  #a3c2fe;
#         }    #T_2bbbc86c_562b_11e8_abb4_1600c1905601r

# %%
h = sorted(result['hh_size_hhinfo'].dropna())  #sorted

fit = stats.norm.pdf(h, np.mean(h), np.std(h))  #this is a fitting indeed

pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title("Distribution of HH Size")
pl.show()

# %%
a = result.gps_location_end.str.split(' ').dropna()
b = pd.DataFrame((item for item in a), columns = ['lat','long','alt','acc'])
b['lat'] = pd.to_numeric(b['lat'], errors='coerce')
b['long'] = pd.to_numeric(b['long'], errors='coerce')
b['ref'] = result['refusal']
b['comp'] = result['incomplete']

# %%
lat = b['lat'].values
lon = b['long'].values
colors = {1 : 'red', 0 : 'blue'}

url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service


map_osm = folium.Map(location=[26.222534, 82],zoom_start=6, control_scale = True, tiles=tileset, attr='USGS style')

#folium.LayerControl().add_to(map_osm)
b.apply(lambda row:folium.CircleMarker(location=[row["lat"], row["long"]], 
                                              radius=1,color=colors[row['comp']])
                                             .add_to(map_osm), axis=1)


iframe = map_osm._repr_html_()
display(HTML(iframe))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import psycopg2
import matplotlib.pyplot as pp
import pylab as pl
import folium
from IPython.display import HTML
import seaborn as sns
from scipy import stats

# %%
HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
result = pd.read_excel('/Users/ryan/Desktop/may14_portaldata.xlsx', encoding= 'utf-8-sig')

result['hh_size_hhinfo'] = pd.to_numeric(result['hh_size_hhinfo'], errors='coerce')

result.loc[result['incomplete'] == 0, 'complete'] = 1
result.loc[result['refusal'] == 1, 'complete'] = 0
result.loc[result['perm_unavail'] == 1, 'complete'] = 0

total = result[['state_intro','refusal','perm_unavail','incomplete','complete']].groupby(['state_intro']).sum()
total['Total Attempted'] = result[['state_intro','scto_uuid']].groupby(['state_intro']).count()

total.loc['All'] = total.sum()
#total.loc['All']
total
# Out:
#              refusal  perm_unavail  incomplete  complete  Total Attempted
# state_intro
# 8                3.0           6.0        51.0      52.0            112.0
# 9                8.0          17.0       334.0     186.0            545.0
# 10               7.0          17.0       315.0     154.0            492.0
# 18               0.0          12.0       174.0     267.0            453.0
# 20               1.0           6.0        95.0      72.0            174.0
# 23               3.0          30.0       236.0     188.0            457.0
# 27               0.0           2.0        28.0      27.0             57.0
# All             22.0          90.0      1233.0     946.0           2290.0

# %%
counts = result[['state_intro','district_id_intro','refusal','incomplete','complete', 'perm_unavail']].groupby(['state_intro','district_id_intro']).sum()

counts['Total Attempted'] = result[['state_intro','district_id_intro','dod_enumerator_id_intro']].groupby(['state_intro','district_id_intro']).count()
counts['% Refusal'] = ((counts['refusal'] / counts['Total Attempted']))
counts['% Incomplete'] = ((counts['incomplete'] / counts['Total Attempted']))
counts['% Unavailable'] = ((counts['perm_unavail'] / counts['Total Attempted']))
counts = counts.drop(columns=['refusal', 'incomplete','perm_unavail'])
counts = counts[['% Refusal','% Unavailable', '% Incomplete','complete','Total Attempted']]

(counts.loc[:]
    .style
    .format({'% Refusal': "{:.1%}", '% Unavailable': "{:.1%}",'% Incomplete': "{:.1%}"})
    .background_gradient(cmap='RdBu', low=0, high=0.2,subset=['complete', 'Total Attempted'])
    .background_gradient(cmap='coolwarm', low=0.5, high=0.1,subset=['% Refusal', '% Incomplete', '% Unavailable']))
# Out:
# <style  type="text/css" >
#     #T_70a92280_57a2_11e8_921b_1600c1905601row0_col0 {
#             background-color:  #a3c2fe;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row0_col1 {
#             background-color:  #cbd8ee;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row0_col2 {
#             background-color:  #f18d6f;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row0_col3 {
#             background-color:  #67001f;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row0_col4 {
#             background-color:  #67001f;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row1_col0 {
#             background-color:  #e36c55;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row1_col1 {
#             background-color:  #dadce0;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row1_col2 {
#             background-color:  #e9d5cb;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row1_col3 {
#             background-color:  #fddbc7;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row1_col4 {
#             background-color:  #f8bda1;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row2_col0 {
#             background-color:  #cedaeb;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row2_col1 {
#             background-color:  #a2c1ff;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row2_col2 {
#             background-color:  #f7af91;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row2_col3 {
#             background-color:  #f0f4f6;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row2_col4 {
#             background-color:  #f6f7f7;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row3_col0 {
#             background-color:  #f7af91;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row3_col1 {
#             background-color:  #bcd2f7;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row3_col2 {
#             background-color:  #eb7d62;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row3_col3 {
#             background-color:  #f0f4f6;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row3_col4 {
#             background-color:  #529dc8;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row4_col0 {
#             background-color:  #a3c2fe;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row4_col1 {
#             background-color:  #c1d4f4;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row4_col2 {
#             background-color:  #d95847;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row4_col3 {
#             background-color:  #f9c2a7;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row4_col4 {
#             background-color:  #bddbea;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row5_col0 {
#             background-color:  #ca3b37;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row5_col1 {
#             background-color:  #d7dce3;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row5_col2 {
#             background-color:  #f49a7b;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row5_col3 {
#             background-color:  #d25849;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row5_col4 {
#             background-color:  #ee9677;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row6_col0 {
#             background-color:  #a3c2fe;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row6_col1 {
#             background-color:  #f2c9b4;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row6_col2 {
#             background-color:  #f08b6e;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row6_col3 {
#             background-color:  #a51429;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row6_col4 {
#             background-color:  #c6413e;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row7_col0 {
#             background-color:  #f7b89c;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row7_col1 {
#             background-color:  #d1dae9;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row7_col2 {
#             background-color:  #f7ad90;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row7_col3 {
#             background-color:  #f5a886;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row7_col4 {
#             background-color:  #f9c2a7;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row8_col0 {
#             background-color:  #e1dad6;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row8_col1 {
#             background-color:  #bfd3f6;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row8_col2 {
#             background-color:  #e67259;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row8_col3 {
#             background-color:  #ce4f45;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row8_col4 {
#             background-color:  #f09c7b;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row9_col0 {
#             background-color:  #a3c2fe;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row9_col1 {
#             background-color:  #c0d4f5;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row9_col2 {
#             background-color:  #cb3e38;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row9_col3 {
#             background-color:  #d6604d;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row9_col4 {
#             background-color:  #fae9df;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row10_col0 {
#             background-color:  #e4d9d2;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row10_col1 {
#             background-color:  #a2c1ff;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row10_col2 {
#             background-color:  #f6a385;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row10_col3 {
#             background-color:  #e8896c;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row10_col4 {
#             background-color:  #e98b6e;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row11_col0 {
#             background-color:  #f5c4ac;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row11_col1 {
#             background-color:  #d7dce3;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row11_col2 {
#             background-color:  #dc5d4a;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row11_col3 {
#             background-color:  #f8bb9e;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row11_col4 {
#             background-color:  #93c6de;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row12_col0 {
#             background-color:  #a3c2fe;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row12_col1 {
#             background-color:  #abc8fd;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row12_col2 {
#             background-color:  #f5c2aa;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row12_col3 {
#             background-color:  #d5e7f1;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row12_col4 {
#             background-color:  #f6f7f7;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row13_col0 {
#             background-color:  #a3c2fe;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row13_col1 {
#             background-color:  #a2c1ff;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row13_col2 {
#             background-color:  #a2c1ff;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row13_col3 {
#             background-color:  #3783bb;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row13_col4 {
#             background-color:  #fbe5d8;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row14_col0 {
#             background-color:  #a3c2fe;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row14_col1 {
#             background-color:  #c0d4f5;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row14_col2 {
#             background-color:  #edd2c3;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row14_col3 {
#             background-color:  #f8bb9e;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row14_col4 {
#             background-color:  #e58368;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601row15_col0 {
#             background-color:  #a3c2fe;
#         }    #T_70a92280_57a2_11e8_921b_1600c1905601r

# %%
h = sorted(result['hh_size_hhinfo'].dropna())  #sorted

fit = stats.norm.pdf(h, np.mean(h), np.std(h))  #this is a fitting indeed

pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title("Distribution of HH Size")
pl.show()

# %%
a = result.gps_location_end.str.split(' ').dropna()
b = pd.DataFrame((item for item in a), columns = ['lat','long','alt','acc'])
b['lat'] = pd.to_numeric(b['lat'], errors='coerce')
b['long'] = pd.to_numeric(b['long'], errors='coerce')
b['ref'] = result['refusal']
b['comp'] = result['incomplete']

# %%
lat = b['lat'].values
lon = b['long'].values
colors = {1 : 'red', 0 : 'blue'}

url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service


map_osm = folium.Map(location=[26.222534, 82],zoom_start=5, control_scale = True, tiles=tileset, attr='USGS style')

#folium.LayerControl().add_to(map_osm)
for row in b.itertuples():
    map_osm.add_child(folium.CircleMarker(location=[row.lat, row.long], radius=1,color=colors[row.comp], 
                                                      prefix='fa'))

legend_html =   '''
                <div style="position: fixed; 
                            background-color:white;
                            bottom: 450px; left: 50px; width: 125px; height: 50px; 
                            border:2px solid grey; z-index:9999; font-size:14px;
                            ">&nbsp; Incomplete &nbsp; <i class="fa fa fa-circle" style="color:red"></i><br>
                              &nbsp; Complete &nbsp; <i class="fa fa fa-circle" style="color:blue"></i>   
                </div>
                ''' 
map_osm.get_root().html.add_child(folium.Element(legend_html)).add_child(folium.Element("<h1>Submitted Forms Mapped by GPS</h1>"))
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

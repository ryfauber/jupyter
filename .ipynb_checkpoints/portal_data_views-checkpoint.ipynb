# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import psycopg2
import matplotlib.pyplot as pp
import pylab as pl
import folium
from IPython.display import HTML
import seaborn as sns
from scipy import stats
from folium.plugins import MarkerCluster

# %%
HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Show Code')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Hide Code')
    }
    code_shown = !code_shown
  }

  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
result = pd.read_excel('/Users/ryan/Desktop/may15_portaldata.xlsx', encoding= 'utf-8-sig')

result['hh_size_hhinfo'] = pd.to_numeric(result['hh_size_hhinfo'], errors='coerce')

result.loc[result['incomplete'] == 0, 'complete'] = 1
result.loc[result['refusal'] == 1, 'complete'] = 0
result.loc[result['perm_unavail'] == 1, 'complete'] = 0

total = result[['state_intro','refusal','perm_unavail','incomplete','complete']].groupby(['state_intro']).sum()
total['Total Attempted'] = result[['state_intro','scto_uuid']].groupby(['state_intro']).count()

total.loc['All'] = total.sum()
#total.loc['All']
total
# Out:
#              refusal  perm_unavail  incomplete  complete  Total Attempted
# state_intro
# 8                5.0          10.0        81.0     100.0            196.0
# 9               11.0          26.0       443.0     267.0            747.0
# 10               9.0          22.0       398.0     198.0            626.0
# 18               0.0          15.0       218.0     362.0            595.0
# 20               3.0           8.0       131.0     105.0            246.0
# 23               4.0          41.0       321.0     258.0            624.0
# 27               1.0           4.0        45.0      36.0             86.0
# All             33.0         126.0      1637.0    1326.0           3120.0

# %%
counts = result[['state_intro','district_id_intro','refusal','incomplete','complete', 'perm_unavail']].groupby(['state_intro','district_id_intro']).sum()

counts['Total Attempted'] = result[['state_intro','district_id_intro','dod_enumerator_id_intro']].groupby(['state_intro','district_id_intro']).count()
counts['% Refusal'] = ((counts['refusal'] / counts['Total Attempted']))
counts['% Incomplete'] = ((counts['incomplete'] / counts['Total Attempted']))
counts['% Unavailable'] = ((counts['perm_unavail'] / counts['Total Attempted']))
counts = counts.drop(columns=['refusal', 'incomplete','perm_unavail'])
counts = counts[['% Refusal','% Unavailable', '% Incomplete','complete','Total Attempted']]

(counts.loc[:]
    .style
    .format({'% Refusal': "{:.1%}", '% Unavailable': "{:.1%}",'% Incomplete': "{:.1%}"})
    .background_gradient(cmap='RdBu', low=0, high=0.2,subset=['complete', 'Total Attempted'])
    .background_gradient(cmap='coolwarm', low=0.5, high=0.1,subset=['% Refusal', '% Incomplete', '% Unavailable']))
# Out:
# <style  type="text/css" >
#     #T_3b9da918_58c0_11e8_9192_1600c1905601row0_col0 {
#             background-color:  #a3c2fe;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row0_col1 {
#             background-color:  #c9d7f0;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row0_col2 {
#             background-color:  #f7b79b;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row0_col3 {
#             background-color:  #67001f;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row0_col4 {
#             background-color:  #67001f;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row1_col0 {
#             background-color:  #f59c7d;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row1_col1 {
#             background-color:  #f0cdbb;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row1_col2 {
#             background-color:  #e0dbd8;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row1_col3 {
#             background-color:  #c2ddec;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row1_col4 {
#             background-color:  #f0f4f6;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row2_col0 {
#             background-color:  #bfd3f6;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row2_col1 {
#             background-color:  #adc9fd;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row2_col2 {
#             background-color:  #f7a98b;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row2_col3 {
#             background-color:  #eaf1f5;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row2_col4 {
#             background-color:  #e4eef4;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row3_col0 {
#             background-color:  #f5c4ac;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row3_col1 {
#             background-color:  #c0d4f5;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row3_col2 {
#             background-color:  #ec8165;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row3_col3 {
#             background-color:  #eff3f5;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row3_col4 {
#             background-color:  #569fc9;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row4_col0 {
#             background-color:  #a3c2fe;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row4_col1 {
#             background-color:  #dadce0;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row4_col2 {
#             background-color:  #e9785d;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row4_col3 {
#             background-color:  #fce0d0;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row4_col4 {
#             background-color:  #a9d1e5;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row5_col0 {
#             background-color:  #ca3b37;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row5_col1 {
#             background-color:  #f7b89c;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row5_col2 {
#             background-color:  #f6a586;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row5_col3 {
#             background-color:  #c84440;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row5_col4 {
#             background-color:  #f3a481;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row6_col0 {
#             background-color:  #a3c2fe;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row6_col1 {
#             background-color:  #f7b79b;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row6_col2 {
#             background-color:  #f59d7e;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row6_col3 {
#             background-color:  #ab162a;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row6_col4 {
#             background-color:  #cc4c44;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row7_col0 {
#             background-color:  #e8d6cc;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row7_col1 {
#             background-color:  #e1dad6;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row7_col2 {
#             background-color:  #f7a889;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row7_col3 {
#             background-color:  #e8896c;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row7_col4 {
#             background-color:  #f7b799;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row8_col0 {
#             background-color:  #cbd8ee;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row8_col1 {
#             background-color:  #c0d4f5;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row8_col2 {
#             background-color:  #ee8669;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row8_col3 {
#             background-color:  #d6604d;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row8_col4 {
#             background-color:  #f4a683;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row9_col0 {
#             background-color:  #a3c2fe;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row9_col1 {
#             background-color:  #ccd9ed;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row9_col2 {
#             background-color:  #ca3b37;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row9_col3 {
#             background-color:  #ab162a;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row9_col4 {
#             background-color:  #f6b394;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row10_col0 {
#             background-color:  #d2dbe8;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row10_col1 {
#             background-color:  #b5cdfa;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row10_col2 {
#             background-color:  #f7b093;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row10_col3 {
#             background-color:  #dc6e57;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row10_col4 {
#             background-color:  #dd7059;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row11_col0 {
#             background-color:  #f6bda2;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row11_col1 {
#             background-color:  #edd1c2;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row11_col2 {
#             background-color:  #d55042;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row11_col3 {
#             background-color:  #e8896c;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row11_col4 {
#             background-color:  #84bcd9;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row12_col0 {
#             background-color:  #a3c2fe;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row12_col1 {
#             background-color:  #adc9fd;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row12_col2 {
#             background-color:  #edd1c2;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row12_col3 {
#             background-color:  #90c4dd;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row12_col4 {
#             background-color:  #eaf1f5;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row13_col0 {
#             background-color:  #a3c2fe;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row13_col1 {
#             background-color:  #a3c2fe;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row13_col2 {
#             background-color:  #a3c2fe;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row13_col3 {
#             background-color:  #3783bb;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row13_col4 {
#             background-color:  #fcdecd;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row14_col0 {
#             background-color:  #a3c2fe;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row14_col1 {
#             background-color:  #c5d6f2;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row14_col2 {
#             background-color:  #e7d7ce;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row14_col3 {
#             background-color:  #f8bb9e;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row14_col4 {
#             background-color:  #e17860;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601row15_col0 {
#             background-color:  #a3c2fe;
#         }    #T_3b9da918_58c0_11e8_9192_1600c1905601r

# %%
h = sorted(result['hh_size_hhinfo'].dropna())  #sorted

fit = stats.norm.pdf(h, np.mean(h), np.std(h))  #this is a fitting indeed

pl.plot(h,fit,'-o')
pl.hist(h,normed=True)
pl.title("Distribution of HH Size")
pl.show()

# %%
a = result.gps_location_end.str.split(' ').dropna()
b = pd.DataFrame((item for item in a), columns = ['lat','long','alt','acc'])
b['lat'] = pd.to_numeric(b['lat'], errors='coerce')
b['long'] = pd.to_numeric(b['long'], errors='coerce')
b['ref'] = result['refusal']
b['comp'] = result['incomplete']

# %%
#grab a random sample from df
)
some_map = folium.Map(location=[subset_of_df[‘INTPTLAT’].mean(), 
   subset_of_df[‘INTPTLONG’].mean()], 
 zoom_start=4)
callback = (‘function (row) {‘ 
             ‘var circle = L.circle(new L.LatLng(row[0], row[1],'          '{color: “red”, radius: 20000});’
             ‘return circle};’)
some_map.add_child(FastMarkerCluster(subset_of_df[[‘INTPTLAT’, ‘INTPTLONG’]].values.tolist(), callback=callback))
some_map

# %%
lat = b['lat'].values
lon = b['long'].values

colors = {1 : 'red', 0 : 'blue'}

url_base = 'http://server.arcgisonline.com/ArcGIS/rest/services/'
service = 'World_Street_Map/MapServer/tile/{z}/{y}/{x}'
tileset = url_base + service


map_osm = folium.Map(location=[b['lat'].mean(), 
   b['long'].mean()],zoom_start=5, control_scale = True, tiles=tileset, attr='USGS style')

mc = folium.plugins.MarkerCluster()

for row in b.itertuples():
    mc.add_child(folium.Marker(location=[row.lat,  row.long]))

map_osm.add_child(mc)

map_osm.get_root().add_child(folium.Element("<h1>Submitted Forms Mapped by GPS</h1>"))
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
